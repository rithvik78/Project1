# %%
import copy # to make a copy of child 
import time # to measure the time of algorithm

# %%
# Data structure that is used to store the puzzle 
class Node:
    def __init__(self,puzzle,cost,depth):
        self.puzzle = puzzle
        self.cost = cost
        self.depth = depth

# %%
# some of the default puzzles that can be used for testing the algorithm 
default_puzzle ={
                    '1':[[1,2,3],[4,5,6],[7,8,0]],
                    '2':[[1,2,3],[4,5,6],[0,7,8]],
                    '3':[[1,2,3],[5,0,6],[4,7,8]],
                    '4':[[1,3,6],[5,0,2],[4,7,8]],
                    '5':[[1,3,6],[5,0,7],[4,8,2]],
                    '6':[[1,6,7],[5,0,3],[4,8,2]],
                    '7':[[7,1,2],[4,8,5],[6,3,0]],
                    '8':[[0,7,2],[4,6,1],[3,5,8]]
                }
# goal state of the puzzle 
goalPuzzle = [[1,2,3],[4,5,6],[7,8,0]]

# %%
# function that finds if the numbers match with the goal state puzzle 
def isValid(puzzle,val):
    for i in range(len(puzzle)):
        for j in range(len(puzzle[i])):
            if puzzle[i][j]==val:
                return i,j
    return -1,-1 # returns -1 if the puzzle match fails

# %%
# Functions for the movements of the blank space in the puzzle 
# Basically swaps the numbers 

def down(root:Node):
    x,y=isValid(root.puzzle,0)
    if x!=0:
        root.puzzle[x][y],root.puzzle[x-1][y]=root.puzzle[x-1][y],root.puzzle[x][y]
        return root
    else:
        return None

def left(root:Node):
    x,y=isValid(root.puzzle,0)
    if y!=2:
        root.puzzle[x][y],root.puzzle[x][y+1]=root.puzzle[x][y+1],root.puzzle[x][y]
        return root
    else:
        return None

def right(root:Node):
    x,y=isValid(root.puzzle,0)
    if y!=0:
        root.puzzle[x][y],root.puzzle[x][y-1]=root.puzzle[x][y-1],root.puzzle[x][y]
        return root
    else:
        return None

def up(root:Node):
    x,y=isValid(root.puzzle,0)
    if x!=2:
        root.puzzle[x][y],root.puzzle[x+1][y]=root.puzzle[x+1][y],root.puzzle[x][y]
        return root
    else:
        return None

# %%
def misplacedTile(root:Node):
    s=0
    for i in range(len(root.puzzle)):
        for j in range(len(root.puzzle[i])):
            if goalPuzzle[i][j]!=root.puzzle[i][j] and all(v!=len(root.puzzle[i])for v in (i,j)):
                s+=1
    return s

# %%
def manhattanDistance(root:Node): # https://www.geeksforgeeks.org/sum-manhattan-distances-pairs-points/
    s=0
    for i in range(len(root.puzzle)):
        for j in range(len(root.puzzle[i])):
            x,y=isValid(goalPuzzle,root.puzzle[i][j])
            if root.puzzle[i][j]!=0:
                s+=abs(x-i)+abs(y-j)
    return s

# %%
def queue_up(node,nodes,queue_function):
    global abc # visited states made global to avoid confusion 
    x=copy.deepcopy(node)
    x=up(x)
    if x is not None:
        x.depth=node.depth+1
        if queue_function=='1':
            x.cost=x.depth + 0
        elif queue_function=='2':
            x.cost=x.depth+misplacedTile(x)
        elif queue_function=='3':
            x.cost=x.depth+manhattanDistance(x)
        if [x.cost,x.puzzle] not in abc:
            nodes.append(x)
            abc.append([x.cost,x.puzzle])
    x=copy.deepcopy(node)
    x=down(x)
    if x is not  None:
        x.depth=node.depth+1
        if queue_function=='1':
            x.cost=x.depth + 0
        elif queue_function=='2':
            x.cost=x.depth+misplacedTile(x)
        elif queue_function=='3':
            x.cost=x.depth+manhattanDistance(x)
        if [x.cost,x.puzzle] not in abc:
            nodes.append(x)
            abc.append([x.cost,x.puzzle])
    x=copy.deepcopy(node)
    x=left(x)
    if x is not None:
        x.depth=node.depth+1
        if queue_function=='1':
            x.cost=x.depth + 0
        if queue_function=='2':
            x.cost=x.depth+misplacedTile(x)
        elif queue_function=='3':
            x.cost=x.depth+manhattanDistance(x)
        if [x.cost,x.puzzle] not in abc:
            nodes.append(x)
            abc.append([x.cost,x.puzzle])
    x=copy.deepcopy(node)
    x=right(x)
    if x is not None:
        x.depth=node.depth+1
        if queue_function=='1':
            x.cost=x.depth + 0
        if queue_function=='2':
            x.cost=x.depth+misplacedTile(x)
        if queue_function=='3':
            x.cost=x.depth+manhattanDistance(x)
        if [x.cost,x.puzzle] not in abc:
            nodes.append(x)
            abc.append([x.cost,x.puzzle])
    nodes.sort(key=lambda x:(x.cost,x.depth))
    print ('\n[-] Exapnading at depth',str(nodes[0].depth),'\n')
    show_puzzle(nodes[0])
    return nodes

# %%
# general-search Algorithm
def generalSearch(root: Node, queue_function): # refered from the lecture slides 
    nodes = [root] # nodes = MAKE-QUEUE(MAKE-NODE(problem.INITIAL-STATE))
    maxi=0 # to update the counter used for loop 
    cnt=0 # count of nodes expanded 
    
    while len(nodes)!=0:
    
        node=nodes.pop(0)
        if node.puzzle == goalPuzzle:
            print('successfull'+' '+str(cnt))
            return node
        nodes=queue_up(node,nodes,queue_function)        
        cnt+=1
        if maxi<len(nodes):
            maxi=len(nodes)
    
    print('no result')
    return None

# %%
def show_puzzle(node: Node):
    for x in node.puzzle:
        for y in x: 
            if y == 0:
                print('_',end=' ')  
                continue  
            print(y,end=' ')
        print()

# %%
choice=int(input("Choose from following: \n1. Use Default Puzzle\n2. Enter Puzzle\nInput: "))
arr=[1,2] # array to manage the inputs 
abc=[] # queue to store visited states

if choice==arr[0]: # choose deafult puzzles 

    print("Default Puzzle selected")
    dif = input('Select the difficulty of the puzzle from a scale of 1 to 8\nInput: ')
    puzzle = default_puzzle[dif]
    # print selected puzzle 
    print ('Selected the puzzle: ')
    for x in puzzle:
        for y in x:
            if y == 0:
                print('_',end=' ')  
                continue  
            print(y,end=' ')
        print()

elif choice == arr[1]: 
     # taking input from user 
     print('Enter puzzle: \n(Use 0 instead of blank space "_")')
     puzzle = []
     n = int(input('Number of rows/columns: '))
     # converting into 2D List
     for i in range(n):
         t = list(map(int,input().split()))
         puzzle.append(t)

# if user inputs input other than 1 or 2 it asks for input again and again 
while(choice>len(arr)or choice<1):
    
    print('Invalid choice')
    
    choice=int(input("Choose from following: \n1. Use Default Puzzle\n2. Enter Puzzle\nInput: "))
    if choice==arr[0]:
        print("Default Puzzle selected")
        dif = input('Select the difficulty of the puzzle from a scale of 1 to 8\nInput: ')
        puzzle = default_puzzle[dif]
        # print selected puzzle 
        print ('Selected the puzzle: ')
        for x in puzzle:
            for y in x:
                if y == 0:
                    print('_',end=' ')  
                    continue  
                print(y,end=' ')
            print()
    
    elif choice == arr[1]: 
    # taking input from user 
        print('Enter puzzle: \n(Use 0 instead of blank space "_")')
        puzzle = []
        n = int(input('Number of rows/columns: '))
        # converting into 2D List
        for i in range(n):
            t = list(map(int,input().split()))
            puzzle.append(t)

# input for the choice of Algorithm 
algChoice =(input('Choose Algorithm from following: \n1. Uniform Cost Search \n2. A* with the misplacedTileplaced Tile heuristic \n3. A* with the Manhattan Distance heuristic\nInput: '))
# Out:
# Choose from following:
# 1. Use Default Puzzle
# 2. Enter Puzzle
# Input: 1
# Default Puzzle selected
# Select the difficulty of the puzzle from a scale of 1 to 8
# Input: 4
# Selected the puzzle:
# 1 3 6
# 5 _ 2
# 4 7 8
# Choose Algorithm from following:
# 1. Uniform Cost Search
# 2. A* with the misplacedTileplaced Tile heuristic
# 3. A* with the Manhattan Distance heuristic
# Input: 3

# %%
root=Node(puzzle,0,0)

start=time.time() # https://stackoverflow.com/questions/7370801/how-do-i-measure-elapsed-time-in-python

result=generalSearch(root,algChoice)

end=time.time() # to measure the time elapsed for the algorithm 

print('Goal state reached!!')
for x in result.puzzle:
    for y in x: 
        if y == 0:
            print('_',end=' ')  
            continue  
        print(y,end=' ')
    print()
print('Solution found at depth', str(result.depth))
print('Algorithm took',str(round((end-start),5)),'seconds to complete')  # https://www.programiz.com/python-programming/methods/built-in/round
# Out:
# [-] Exapnading at depth 1
#
# 1 3 6
# 5 2 _
# 4 7 8
#
# [-] Exapnading at depth 1
#
# 1 3 6
# _ 5 2
# 4 7 8
#
# [-] Exapnading at depth 2
#
# 1 3 _
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 2
#
# 1 3 6
# 4 5 2
# _ 7 8
#
# [-] Exapnading at depth 3
#
# 1 _ 3
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 3
#
# 1 3 6
# 4 5 2
# 7 _ 8
#
# [-] Exapnading at depth 4
#
# 1 2 3
# 5 _ 6
# 4 7 8
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 4 5 2
# 7 8 _
#
# [-] Exapnading at depth 5
#
# 1 2 3
# _ 5 6
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 2 3
# 4 5 6
# _ 7 8
#
# [-] Exapnading at depth 7
#
# 1 2 3
# 4 5 6
# 7 _ 8
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 4 5 6
# 7 8 _
# successfull 12
# Goal state reached!!
# 1 2 3
# 4 5 6
# 7 8 _
# Solution found at depth 8
# Algorithm took 0.02281 seconds to complete

# %% [markdown]
# # Compiled the code 3 times for the same puzzle with depth 4 in order to compare the time

# %%
choice=int(input("Choose from following: \n1. Use Default Puzzle\n2. Enter Puzzle\nInput: "))
arr=[1,2] # array to manage the inputs 
abc=[] # queue to store visited states

if choice==arr[0]: # choose deafult puzzles 

    print("Default Puzzle selected")
    dif = input('Select the difficulty of the puzzle from a scale of 1 to 8\nInput: ')
    puzzle = default_puzzle[dif]
    # print selected puzzle 
    print ('Selected the puzzle: ')
    for x in puzzle:
        for y in x:
            if y == 0:
                print('_',end=' ')  
                continue  
            print(y,end=' ')
        print()

elif choice == arr[1]: 
     # taking input from user 
     print('Enter puzzle: \n(Use 0 instead of blank space "_")')
     puzzle = []
     n = int(input('Number of rows/columns: '))
     # converting into 2D List
     for i in range(n):
         t = list(map(int,input().split()))
         puzzle.append(t)

# if user inputs input other than 1 or 2 it asks for input again and again 
while(choice>len(arr)or choice<1):
    
    print('Invalid choice')
    
    choice=int(input("Choose from following: \n1. Use Default Puzzle\n2. Enter Puzzle\nInput: "))
    if choice==arr[0]:
        print("Default Puzzle selected")
        dif = input('Select the difficulty of the puzzle from a scale of 1 to 8\nInput: ')
        puzzle = default_puzzle[dif]
        # print selected puzzle 
        print ('Selected the puzzle: ')
        for x in puzzle:
            for y in x:
                if y == 0:
                    print('_',end=' ')  
                    continue  
                print(y,end=' ')
            print()
    
    elif choice == arr[1]: 
    # taking input from user 
        print('Enter puzzle: \n(Use 0 instead of blank space "_")')
        puzzle = []
        n = int(input('Number of rows/columns: '))
        # converting into 2D List
        for i in range(n):
            t = list(map(int,input().split()))
            puzzle.append(t)

# input for the choice of Algorithm 
algChoice =(input('Choose Algorithm from following: \n1. Uniform Cost Search \n2. A* with the misplacedTileplaced Tile heuristic \n3. A* with the Manhattan Distance heuristic\nInput: '))
root=Node(puzzle,0,0)

start=time.time() # https://stackoverflow.com/questions/7370801/how-do-i-measure-elapsed-time-in-python

result=generalSearch(root,algChoice)

end=time.time() # to measure the time elapsed for the algorithm 

print('Goal state reached!!')
for x in result.puzzle:
    for y in x: 
        if y == 0:
            print('_',end=' ')  
            continue  
        print(y,end=' ')
    print()
print('Solution found at depth', str(result.depth))
print('Algorithm took',str(round((end-start),5)),'seconds to complete')  # https://www.programiz.com/python-programming/methods/built-in/round
# Out:
# Choose from following:
# 1. Use Default Puzzle
# 2. Enter Puzzle
# Input: 1
# Default Puzzle selected
# Select the difficulty of the puzzle from a scale of 1 to 8
# Input: 4
# Selected the puzzle:
# 1 3 6
# 5 _ 2
# 4 7 8
# Choose Algorithm from following:
# 1. Uniform Cost Search
# 2. A* with the misplacedTileplaced Tile heuristic
# 3. A* with the Manhattan Distance heuristic
# Input: 2
#
# [-] Exapnading at depth 1
#
# 1 3 6
# _ 5 2
# 4 7 8
#
# [-] Exapnading at depth 2
#
# 1 3 6
# 4 5 2
# _ 7 8
#
# [-] Exapnading at depth 3
#
# 1 3 6
# 4 5 2
# 7 _ 8
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 4 5 2
# 7 8 _
#
# [-] Exapnading at depth 1
#
# 1 3 6
# 5 7 2
# 4 _ 8
#
# [-] Exapnading at depth 2
#
# 1 3 6
# 5 7 2
# 4 8 _
#
# [-] Exapnading at depth 1
#
# 1 _ 6
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 1
#
# 1 3 6
# 5 2 _
# 4 7 8
#
# [-] Exapnading at depth 2
#
# 1 3 6
# 5 2 8
# 4 7 _
#
# [-] Exapnading at depth 2
#
# 1 3 _
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 3
#
# 1 _ 3
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 4
#
# 1 2 3
# 5 _ 6
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 1 3 6
# 4 5 _
# 7 8 2
#
# [-] Exapnading at depth 5
#
# 1 2 3
# _ 5 6
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 4 5 2
# 7 8 _
#
# [-] Exapnading at depth 6
#
# 1 3 _
# 4 5 6
# 7 8 2
#
# [-] Exapnading at depth 6
#
# 1 2 3
# 4 5 6
# _ 7 8
#
# [-] Exapnading at depth 7
#
# 1 _ 3
# 4 5 6
# 7 8 2
#
# [-] Exapnading at depth 7
#
# 1 2 3
# 4 5 6
# 7 _ 8
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 4 5 6
# 7 8 _
# successfull 20
# Goal state reached!!
# 1 2 3
# 4 5 6
# 7 8 _
# Solution found at depth 8
# Algorithm took 0.04042 seconds to complete

# %%
choice=int(input("Choose from following: \n1. Use Default Puzzle\n2. Enter Puzzle\nInput: "))
arr=[1,2] # array to manage the inputs 
abc=[] # queue to store visited states

if choice==arr[0]: # choose deafult puzzles 

    print("Default Puzzle selected")
    dif = input('Select the difficulty of the puzzle from a scale of 1 to 8\nInput: ')
    puzzle = default_puzzle[dif]
    # print selected puzzle 
    print ('Selected the puzzle: ')
    for x in puzzle:
        for y in x:
            if y == 0:
                print('_',end=' ')  
                continue  
            print(y,end=' ')
        print()

elif choice == arr[1]: 
     # taking input from user 
     print('Enter puzzle: \n(Use 0 instead of blank space "_")')
     puzzle = []
     n = int(input('Number of rows/columns: '))
     # converting into 2D List
     for i in range(n):
         t = list(map(int,input().split()))
         puzzle.append(t)

# if user inputs input other than 1 or 2 it asks for input again and again 
while(choice>len(arr)or choice<1):
    
    print('Invalid choice')
    
    choice=int(input("Choose from following: \n1. Use Default Puzzle\n2. Enter Puzzle\nInput: "))
    if choice==arr[0]:
        print("Default Puzzle selected")
        dif = input('Select the difficulty of the puzzle from a scale of 1 to 8\nInput: ')
        puzzle = default_puzzle[dif]
        # print selected puzzle 
        print ('Selected the puzzle: ')
        for x in puzzle:
            for y in x:
                if y == 0:
                    print('_',end=' ')  
                    continue  
                print(y,end=' ')
            print()
    
    elif choice == arr[1]: 
    # taking input from user 
        print('Enter puzzle: \n(Use 0 instead of blank space "_")')
        puzzle = []
        n = int(input('Number of rows/columns: '))
        # converting into 2D List
        for i in range(n):
            t = list(map(int,input().split()))
            puzzle.append(t)

# input for the choice of Algorithm 
algChoice =(input('Choose Algorithm from following: \n1. Uniform Cost Search \n2. A* with the misplacedTileplaced Tile heuristic \n3. A* with the Manhattan Distance heuristic\nInput: '))
root=Node(puzzle,0,0)

start=time.time() # https://stackoverflow.com/questions/7370801/how-do-i-measure-elapsed-time-in-python

result=generalSearch(root,algChoice)

end=time.time() # to measure the time elapsed for the algorithm 

print('Goal state reached!!')
for x in result.puzzle:
    for y in x: 
        if y == 0:
            print('_',end=' ')  
            continue  
        print(y,end=' ')
    print()
print('Solution found at depth', str(result.depth))
print('Algorithm took',str(round((end-start),5)),'seconds to complete')  # https://www.programiz.com/python-programming/methods/built-in/round
# Out:
# Choose from following:
# 1. Use Default Puzzle
# 2. Enter Puzzle
# Input: 1
# Default Puzzle selected
# Select the difficulty of the puzzle from a scale of 1 to 8
# Input: 4
# Selected the puzzle:
# 1 3 6
# 5 _ 2
# 4 7 8
# Choose Algorithm from following:
# 1. Uniform Cost Search
# 2. A* with the misplacedTileplaced Tile heuristic
# 3. A* with the Manhattan Distance heuristic
# Input: 1
#
# [-] Exapnading at depth 1
#
# 1 3 6
# 5 7 2
# 4 _ 8
#
# [-] Exapnading at depth 1
#
# 1 _ 6
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 1
#
# 1 3 6
# 5 2 _
# 4 7 8
#
# [-] Exapnading at depth 1
#
# 1 3 6
# _ 5 2
# 4 7 8
#
# [-] Exapnading at depth 2
#
# 1 3 6
# 5 _ 2
# 4 7 8
#
# [-] Exapnading at depth 2
#
# 1 3 6
# 5 7 2
# 4 8 _
#
# [-] Exapnading at depth 2
#
# 1 3 6
# 5 7 2
# _ 4 8
#
# [-] Exapnading at depth 2
#
# 1 6 _
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 2
#
# _ 1 6
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 2
#
# 1 3 6
# 5 2 8
# 4 7 _
#
# [-] Exapnading at depth 2
#
# 1 3 _
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 2
#
# 1 3 6
# 4 5 2
# _ 7 8
#
# [-] Exapnading at depth 2
#
# _ 3 6
# 1 5 2
# 4 7 8
#
# [-] Exapnading at depth 3
#
# 1 3 6
# 5 7 2
# 4 _ 8
#
# [-] Exapnading at depth 3
#
# 1 _ 6
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 3
#
# 1 3 6
# 5 2 _
# 4 7 8
#
# [-] Exapnading at depth 3
#
# 1 3 6
# _ 5 2
# 4 7 8
#
# [-] Exapnading at depth 3
#
# 1 3 6
# 5 7 _
# 4 8 2
#
# [-] Exapnading at depth 3
#
# 1 3 6
# _ 7 2
# 5 4 8
#
# [-] Exapnading at depth 3
#
# 1 6 2
# 5 3 _
# 4 7 8
#
# [-] Exapnading at depth 3
#
# 5 1 6
# _ 3 2
# 4 7 8
#
# [-] Exapnading at depth 3
#
# 1 3 6
# 5 2 8
# 4 _ 7
#
# [-] Exapnading at depth 3
#
# 1 _ 3
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 3
#
# 1 3 6
# 4 5 2
# 7 _ 8
#
# [-] Exapnading at depth 3
#
# 3 _ 6
# 1 5 2
# 4 7 8
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 5 _ 2
# 4 7 8
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 5 7 2
# 4 8 _
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 5 7 2
# _ 4 8
#
# [-] Exapnading at depth 4
#
# 1 6 _
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 4
#
# _ 1 6
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 5 2 8
# 4 7 _
#
# [-] Exapnading at depth 4
#
# 1 3 _
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 4 5 2
# _ 7 8
#
# [-] Exapnading at depth 4
#
# _ 3 6
# 1 5 2
# 4 7 8
#
# [-] Exapnading at depth 4
#
# 1 3 _
# 5 7 6
# 4 8 2
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 5 _ 7
# 4 8 2
#
# [-] Exapnading at depth 4
#
# _ 3 6
# 1 7 2
# 5 4 8
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 7 _ 2
# 5 4 8
#
# [-] Exapnading at depth 4
#
# 1 6 2
# 5 3 8
# 4 7 _
#
# [-] Exapnading at depth 4
#
# 1 6 2
# 5 _ 3
# 4 7 8
#
# [-] Exapnading at depth 4
#
# 5 1 6
# 4 3 2
# _ 7 8
#
# [-] Exapnading at depth 4
#
# 5 1 6
# 3 _ 2
# 4 7 8
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 5 _ 8
# 4 2 7
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 5 2 8
# _ 4 7
#
# [-] Exapnading at depth 4
#
# 1 2 3
# 5 _ 6
# 4 7 8
#
# [-] Exapnading at depth 4
#
# _ 1 3
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 4 _ 2
# 7 5 8
#
# [-] Exapnading at depth 4
#
# 1 3 6
# 4 5 2
# 7 8 _
#
# [-] Exapnading at depth 4
#
# 3 5 6
# 1 _ 2
# 4 7 8
#
# [-] Exapnading at depth 4
#
# 3 6 _
# 1 5 2
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 1 3 6
# 5 7 2
# 4 _ 8
#
# [-] Exapnading at depth 5
#
# 1 _ 6
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 1 3 6
# 5 2 _
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 1 3 6
# _ 5 2
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 1 3 6
# 5 7 _
# 4 8 2
#
# [-] Exapnading at depth 5
#
# 1 3 6
# _ 7 2
# 5 4 8
#
# [-] Exapnading at depth 5
#
# 1 6 2
# 5 3 _
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 5 1 6
# _ 3 2
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 1 3 6
# 5 2 8
# 4 _ 7
#
# [-] Exapnading at depth 5
#
# 1 _ 3
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 1 3 6
# 4 5 2
# 7 _ 8
#
# [-] Exapnading at depth 5
#
# 3 _ 6
# 1 5 2
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 1 _ 3
# 5 7 6
# 4 8 2
#
# [-] Exapnading at depth 5
#
# 1 3 6
# 5 8 7
# 4 _ 2
#
# [-] Exapnading at depth 5
#
# 1 _ 6
# 5 3 7
# 4 8 2
#
# [-] Exapnading at depth 5
#
# 1 3 6
# _ 5 7
# 4 8 2
#
# [-] Exapnading at depth 5
#
# 3 _ 6
# 1 7 2
# 5 4 8
#
# [-] Exapnading at depth 5
#
# 1 3 6
# 7 4 2
# 5 _ 8
#
# [-] Exapnading at depth 5
#
# 1 _ 6
# 7 3 2
# 5 4 8
#
# [-] Exapnading at depth 5
#
# 1 3 6
# 7 2 _
# 5 4 8
#
# [-] Exapnading at depth 5
#
# 1 6 2
# 5 3 8
# 4 _ 7
#
# [-] Exapnading at depth 5
#
# 1 6 2
# 5 7 3
# 4 _ 8
#
# [-] Exapnading at depth 5
#
# 1 _ 2
# 5 6 3
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 1 6 2
# _ 5 3
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 5 1 6
# 4 3 2
# 7 _ 8
#
# [-] Exapnading at depth 5
#
# 5 1 6
# 3 7 2
# 4 _ 8
#
# [-] Exapnading at depth 5
#
# 5 _ 6
# 3 1 2
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 5 1 6
# 3 2 _
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 1 _ 6
# 5 3 8
# 4 2 7
#
# [-] Exapnading at depth 5
#
# 1 3 6
# 5 8 _
# 4 2 7
#
# [-] Exapnading at depth 5
#
# 1 3 6
# _ 5 8
# 4 2 7
#
# [-] Exapnading at depth 5
#
# 1 3 6
# _ 2 8
# 5 4 7
#
# [-] Exapnading at depth 5
#
# 1 2 3
# 5 7 6
# 4 _ 8
#
# [-] Exapnading at depth 5
#
# 1 2 3
# 5 6 _
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 1 2 3
# _ 5 6
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 5 1 3
# _ 2 6
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 1 _ 6
# 4 3 2
# 7 5 8
#
# [-] Exapnading at depth 5
#
# 1 3 6
# 4 2 _
# 7 5 8
#
# [-] Exapnading at depth 5
#
# 1 3 6
# _ 4 2
# 7 5 8
#
# [-] Exapnading at depth 5
#
# 1 3 6
# 4 5 _
# 7 8 2
#
# [-] Exapnading at depth 5
#
# 3 5 6
# 1 7 2
# 4 _ 8
#
# [-] Exapnading at depth 5
#
# 3 5 6
# 1 2 _
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 3 5 6
# _ 1 2
# 4 7 8
#
# [-] Exapnading at depth 5
#
# 3 6 2
# 1 5 _
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 5 _ 2
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 5 7 2
# 4 8 _
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 5 7 2
# _ 4 8
#
# [-] Exapnading at depth 6
#
# 1 6 _
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 6
#
# _ 1 6
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 5 2 8
# 4 7 _
#
# [-] Exapnading at depth 6
#
# 1 3 _
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 4 5 2
# _ 7 8
#
# [-] Exapnading at depth 6
#
# _ 3 6
# 1 5 2
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 3 _
# 5 7 6
# 4 8 2
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 5 _ 7
# 4 8 2
#
# [-] Exapnading at depth 6
#
# _ 3 6
# 1 7 2
# 5 4 8
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 7 _ 2
# 5 4 8
#
# [-] Exapnading at depth 6
#
# 1 6 2
# 5 3 8
# 4 7 _
#
# [-] Exapnading at depth 6
#
# 1 6 2
# 5 _ 3
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 5 1 6
# 4 3 2
# _ 7 8
#
# [-] Exapnading at depth 6
#
# 5 1 6
# 3 _ 2
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 5 _ 8
# 4 2 7
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 5 2 8
# _ 4 7
#
# [-] Exapnading at depth 6
#
# 1 2 3
# 5 _ 6
# 4 7 8
#
# [-] Exapnading at depth 6
#
# _ 1 3
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 4 _ 2
# 7 5 8
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 4 5 2
# 7 8 _
#
# [-] Exapnading at depth 6
#
# 3 5 6
# 1 _ 2
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 3 6 _
# 1 5 2
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 7 3
# 5 _ 6
# 4 8 2
#
# [-] Exapnading at depth 6
#
# _ 1 3
# 5 7 6
# 4 8 2
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 5 8 7
# 4 2 _
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 5 8 7
# _ 4 2
#
# [-] Exapnading at depth 6
#
# 1 6 _
# 5 3 7
# 4 8 2
#
# [-] Exapnading at depth 6
#
# _ 1 6
# 5 3 7
# 4 8 2
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 4 5 7
# _ 8 2
#
# [-] Exapnading at depth 6
#
# _ 3 6
# 1 5 7
# 4 8 2
#
# [-] Exapnading at depth 6
#
# 3 7 6
# 1 _ 2
# 5 4 8
#
# [-] Exapnading at depth 6
#
# 3 6 _
# 1 7 2
# 5 4 8
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 7 4 2
# 5 8 _
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 7 4 2
# _ 5 8
#
# [-] Exapnading at depth 6
#
# 1 6 _
# 7 3 2
# 5 4 8
#
# [-] Exapnading at depth 6
#
# _ 1 6
# 7 3 2
# 5 4 8
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 7 2 8
# 5 4 _
#
# [-] Exapnading at depth 6
#
# 1 3 _
# 7 2 6
# 5 4 8
#
# [-] Exapnading at depth 6
#
# 1 6 2
# 5 _ 8
# 4 3 7
#
# [-] Exapnading at depth 6
#
# 1 6 2
# 5 3 8
# _ 4 7
#
# [-] Exapnading at depth 6
#
# 1 6 2
# 5 7 3
# 4 8 _
#
# [-] Exapnading at depth 6
#
# 1 6 2
# 5 7 3
# _ 4 8
#
# [-] Exapnading at depth 6
#
# 1 2 _
# 5 6 3
# 4 7 8
#
# [-] Exapnading at depth 6
#
# _ 1 2
# 5 6 3
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 6 2
# 4 5 3
# _ 7 8
#
# [-] Exapnading at depth 6
#
# _ 6 2
# 1 5 3
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 5 1 6
# 4 _ 2
# 7 3 8
#
# [-] Exapnading at depth 6
#
# 5 1 6
# 4 3 2
# 7 8 _
#
# [-] Exapnading at depth 6
#
# 5 1 6
# 3 7 2
# 4 8 _
#
# [-] Exapnading at depth 6
#
# 5 1 6
# 3 7 2
# _ 4 8
#
# [-] Exapnading at depth 6
#
# 5 6 _
# 3 1 2
# 4 7 8
#
# [-] Exapnading at depth 6
#
# _ 5 6
# 3 1 2
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 5 1 6
# 3 2 8
# 4 7 _
#
# [-] Exapnading at depth 6
#
# 5 1 _
# 3 2 6
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 6 _
# 5 3 8
# 4 2 7
#
# [-] Exapnading at depth 6
#
# _ 1 6
# 5 3 8
# 4 2 7
#
# [-] Exapnading at depth 6
#
# 1 3 _
# 5 8 6
# 4 2 7
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 4 5 8
# _ 2 7
#
# [-] Exapnading at depth 6
#
# _ 3 6
# 1 5 8
# 4 2 7
#
# [-] Exapnading at depth 6
#
# _ 3 6
# 1 2 8
# 5 4 7
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 2 _ 8
# 5 4 7
#
# [-] Exapnading at depth 6
#
# 1 2 3
# 5 7 6
# 4 8 _
#
# [-] Exapnading at depth 6
#
# 1 2 3
# 5 7 6
# _ 4 8
#
# [-] Exapnading at depth 6
#
# 1 2 3
# 5 6 8
# 4 7 _
#
# [-] Exapnading at depth 6
#
# 1 2 3
# 4 5 6
# _ 7 8
#
# [-] Exapnading at depth 6
#
# _ 2 3
# 1 5 6
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 5 1 3
# 4 2 6
# _ 7 8
#
# [-] Exapnading at depth 6
#
# 5 1 3
# 2 _ 6
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 1 6 _
# 4 3 2
# 7 5 8
#
# [-] Exapnading at depth 6
#
# _ 1 6
# 4 3 2
# 7 5 8
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 4 2 8
# 7 5 _
#
# [-] Exapnading at depth 6
#
# 1 3 _
# 4 2 6
# 7 5 8
#
# [-] Exapnading at depth 6
#
# _ 3 6
# 1 4 2
# 7 5 8
#
# [-] Exapnading at depth 6
#
# 1 3 _
# 4 5 6
# 7 8 2
#
# [-] Exapnading at depth 6
#
# 1 3 6
# 4 _ 5
# 7 8 2
#
# [-] Exapnading at depth 6
#
# 3 5 6
# 1 7 2
# 4 8 _
#
# [-] Exapnading at depth 6
#
# 3 5 6
# 1 7 2
# _ 4 8
#
# [-] Exapnading at depth 6
#
# 3 5 6
# 1 2 8
# 4 7 _
#
# [-] Exapnading at depth 6
#
# 3 5 _
# 1 2 6
# 4 7 8
#
# [-] Exapnading at depth 6
#
# 3 5 6
# 4 1 2
# _ 7 8
#
# [-] Exapnading at depth 6
#
# 3 6 2
# 1 5 8
# 4 7 _
#
# [-] Exapnading at depth 6
#
# 3 6 2
# 1 _ 5
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 5 7 2
# 4 _ 8
#
# [-] Exapnading at depth 7
#
# 1 _ 6
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 5 2 _
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# _ 5 2
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 5 7 _
# 4 8 2
#
# [-] Exapnading at depth 7
#
# 1 3 6
# _ 7 2
# 5 4 8
#
# [-] Exapnading at depth 7
#
# 1 6 2
# 5 3 _
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 5 1 6
# _ 3 2
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 5 2 8
# 4 _ 7
#
# [-] Exapnading at depth 7
#
# 1 _ 3
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 4 5 2
# 7 _ 8
#
# [-] Exapnading at depth 7
#
# 3 _ 6
# 1 5 2
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 _ 3
# 5 7 6
# 4 8 2
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 5 8 7
# 4 _ 2
#
# [-] Exapnading at depth 7
#
# 1 _ 6
# 5 3 7
# 4 8 2
#
# [-] Exapnading at depth 7
#
# 1 3 6
# _ 5 7
# 4 8 2
#
# [-] Exapnading at depth 7
#
# 3 _ 6
# 1 7 2
# 5 4 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 7 4 2
# 5 _ 8
#
# [-] Exapnading at depth 7
#
# 1 _ 6
# 7 3 2
# 5 4 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 7 2 _
# 5 4 8
#
# [-] Exapnading at depth 7
#
# 1 6 2
# 5 3 8
# 4 _ 7
#
# [-] Exapnading at depth 7
#
# 1 6 2
# 5 7 3
# 4 _ 8
#
# [-] Exapnading at depth 7
#
# 1 _ 2
# 5 6 3
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 6 2
# _ 5 3
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 5 1 6
# 4 3 2
# 7 _ 8
#
# [-] Exapnading at depth 7
#
# 5 1 6
# 3 7 2
# 4 _ 8
#
# [-] Exapnading at depth 7
#
# 5 _ 6
# 3 1 2
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 5 1 6
# 3 2 _
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 _ 6
# 5 3 8
# 4 2 7
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 5 8 _
# 4 2 7
#
# [-] Exapnading at depth 7
#
# 1 3 6
# _ 5 8
# 4 2 7
#
# [-] Exapnading at depth 7
#
# 1 3 6
# _ 2 8
# 5 4 7
#
# [-] Exapnading at depth 7
#
# 1 2 3
# 5 7 6
# 4 _ 8
#
# [-] Exapnading at depth 7
#
# 1 2 3
# 5 6 _
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 2 3
# _ 5 6
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 5 1 3
# _ 2 6
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 _ 6
# 4 3 2
# 7 5 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 4 2 _
# 7 5 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# _ 4 2
# 7 5 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 4 5 _
# 7 8 2
#
# [-] Exapnading at depth 7
#
# 3 5 6
# 1 7 2
# 4 _ 8
#
# [-] Exapnading at depth 7
#
# 3 5 6
# 1 2 _
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 3 5 6
# _ 1 2
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 3 6 2
# 1 5 _
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 7 3
# 5 8 6
# 4 _ 2
#
# [-] Exapnading at depth 7
#
# 1 7 3
# 5 6 _
# 4 8 2
#
# [-] Exapnading at depth 7
#
# 1 7 3
# _ 5 6
# 4 8 2
#
# [-] Exapnading at depth 7
#
# 5 1 3
# _ 7 6
# 4 8 2
#
# [-] Exapnading at depth 7
#
# 1 3 6
# _ 8 7
# 5 4 2
#
# [-] Exapnading at depth 7
#
# 1 6 7
# 5 3 _
# 4 8 2
#
# [-] Exapnading at depth 7
#
# 5 1 6
# _ 3 7
# 4 8 2
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 4 5 7
# 8 _ 2
#
# [-] Exapnading at depth 7
#
# 3 _ 6
# 1 5 7
# 4 8 2
#
# [-] Exapnading at depth 7
#
# 3 7 6
# 1 4 2
# 5 _ 8
#
# [-] Exapnading at depth 7
#
# 3 7 6
# 1 2 _
# 5 4 8
#
# [-] Exapnading at depth 7
#
# 3 7 6
# _ 1 2
# 5 4 8
#
# [-] Exapnading at depth 7
#
# 3 6 2
# 1 7 _
# 5 4 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 7 4 _
# 5 8 2
#
# [-] Exapnading at depth 7
#
# 1 6 2
# 7 3 _
# 5 4 8
#
# [-] Exapnading at depth 7
#
# 7 1 6
# _ 3 2
# 5 4 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 7 2 8
# 5 _ 4
#
# [-] Exapnading at depth 7
#
# 1 _ 3
# 7 2 6
# 5 4 8
#
# [-] Exapnading at depth 7
#
# 1 _ 2
# 5 6 8
# 4 3 7
#
# [-] Exapnading at depth 7
#
# 1 6 2
# 5 8 _
# 4 3 7
#
# [-] Exapnading at depth 7
#
# 1 6 2
# _ 5 8
# 4 3 7
#
# [-] Exapnading at depth 7
#
# 1 6 2
# _ 3 8
# 5 4 7
#
# [-] Exapnading at depth 7
#
# 1 6 2
# 5 7 _
# 4 8 3
#
# [-] Exapnading at depth 7
#
# 1 6 2
# _ 7 3
# 5 4 8
#
# [-] Exapnading at depth 7
#
# 5 1 2
# _ 6 3
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 6 2
# 4 5 3
# 7 _ 8
#
# [-] Exapnading at depth 7
#
# 6 _ 2
# 1 5 3
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 5 _ 6
# 4 1 2
# 7 3 8
#
# [-] Exapnading at depth 7
#
# 5 1 6
# 4 2 _
# 7 3 8
#
# [-] Exapnading at depth 7
#
# 5 1 6
# _ 4 2
# 7 3 8
#
# [-] Exapnading at depth 7
#
# 5 1 6
# 4 3 _
# 7 8 2
#
# [-] Exapnading at depth 7
#
# 5 1 6
# 3 7 _
# 4 8 2
#
# [-] Exapnading at depth 7
#
# 5 1 6
# _ 7 2
# 3 4 8
#
# [-] Exapnading at depth 7
#
# 5 6 2
# 3 1 _
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 5 1 6
# 3 2 8
# 4 _ 7
#
# [-] Exapnading at depth 7
#
# 5 _ 1
# 3 2 6
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 6 8
# 5 3 _
# 4 2 7
#
# [-] Exapnading at depth 7
#
# 5 1 6
# _ 3 8
# 4 2 7
#
# [-] Exapnading at depth 7
#
# 1 _ 3
# 5 8 6
# 4 2 7
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 4 5 8
# 2 _ 7
#
# [-] Exapnading at depth 7
#
# 3 _ 6
# 1 5 8
# 4 2 7
#
# [-] Exapnading at depth 7
#
# 3 _ 6
# 1 2 8
# 5 4 7
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 2 4 8
# 5 _ 7
#
# [-] Exapnading at depth 7
#
# 1 _ 6
# 2 3 8
# 5 4 7
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 2 8 _
# 5 4 7
#
# [-] Exapnading at depth 7
#
# 1 2 3
# 5 7 _
# 4 8 6
#
# [-] Exapnading at depth 7
#
# 1 2 3
# _ 7 6
# 5 4 8
#
# [-] Exapnading at depth 7
#
# 1 2 3
# 5 6 8
# 4 _ 7
#
# [-] Exapnading at depth 7
#
# 1 2 3
# 4 5 6
# 7 _ 8
#
# [-] Exapnading at depth 7
#
# 2 _ 3
# 1 5 6
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 5 1 3
# 4 2 6
# 7 _ 8
#
# [-] Exapnading at depth 7
#
# 5 1 3
# 2 7 6
# 4 _ 8
#
# [-] Exapnading at depth 7
#
# 5 _ 3
# 2 1 6
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 5 1 3
# 2 6 _
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 1 6 2
# 4 3 _
# 7 5 8
#
# [-] Exapnading at depth 7
#
# 4 1 6
# _ 3 2
# 7 5 8
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 4 2 8
# 7 _ 5
#
# [-] Exapnading at depth 7
#
# 1 _ 3
# 4 2 6
# 7 5 8
#
# [-] Exapnading at depth 7
#
# 3 _ 6
# 1 4 2
# 7 5 8
#
# [-] Exapnading at depth 7
#
# 1 _ 3
# 4 5 6
# 7 8 2
#
# [-] Exapnading at depth 7
#
# 1 3 6
# 4 8 5
# 7 _ 2
#
# [-] Exapnading at depth 7
#
# 1 _ 6
# 4 3 5
# 7 8 2
#
# [-] Exapnading at depth 7
#
# 1 3 6
# _ 4 5
# 7 8 2
#
# [-] Exapnading at depth 7
#
# 3 5 6
# 1 7 _
# 4 8 2
#
# [-] Exapnading at depth 7
#
# 3 5 6
# _ 7 2
# 1 4 8
#
# [-] Exapnading at depth 7
#
# 3 5 6
# 1 2 8
# 4 _ 7
#
# [-] Exapnading at depth 7
#
# 3 _ 5
# 1 2 6
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 3 5 6
# 4 1 2
# 7 _ 8
#
# [-] Exapnading at depth 7
#
# 3 6 2
# 1 5 8
# 4 _ 7
#
# [-] Exapnading at depth 7
#
# 3 6 2
# 1 7 5
# 4 _ 8
#
# [-] Exapnading at depth 7
#
# 3 _ 2
# 1 6 5
# 4 7 8
#
# [-] Exapnading at depth 7
#
# 3 6 2
# _ 1 5
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 5 _ 2
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 5 7 2
# 4 8 _
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 5 7 2
# _ 4 8
#
# [-] Exapnading at depth 8
#
# 1 6 _
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 8
#
# _ 1 6
# 5 3 2
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 5 2 8
# 4 7 _
#
# [-] Exapnading at depth 8
#
# 1 3 _
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 4 5 2
# _ 7 8
#
# [-] Exapnading at depth 8
#
# _ 3 6
# 1 5 2
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 3 _
# 5 7 6
# 4 8 2
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 5 _ 7
# 4 8 2
#
# [-] Exapnading at depth 8
#
# _ 3 6
# 1 7 2
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 7 _ 2
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 5 3 8
# 4 7 _
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 5 _ 3
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 4 3 2
# _ 7 8
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 3 _ 2
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 5 _ 8
# 4 2 7
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 5 2 8
# _ 4 7
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 5 _ 6
# 4 7 8
#
# [-] Exapnading at depth 8
#
# _ 1 3
# 5 2 6
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 4 _ 2
# 7 5 8
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 4 5 2
# 7 8 _
#
# [-] Exapnading at depth 8
#
# 3 5 6
# 1 _ 2
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 3 6 _
# 1 5 2
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 7 3
# 5 _ 6
# 4 8 2
#
# [-] Exapnading at depth 8
#
# _ 1 3
# 5 7 6
# 4 8 2
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 5 8 7
# 4 2 _
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 5 8 7
# _ 4 2
#
# [-] Exapnading at depth 8
#
# 1 6 _
# 5 3 7
# 4 8 2
#
# [-] Exapnading at depth 8
#
# _ 1 6
# 5 3 7
# 4 8 2
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 4 5 7
# _ 8 2
#
# [-] Exapnading at depth 8
#
# _ 3 6
# 1 5 7
# 4 8 2
#
# [-] Exapnading at depth 8
#
# 3 7 6
# 1 _ 2
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 3 6 _
# 1 7 2
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 7 4 2
# 5 8 _
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 7 4 2
# _ 5 8
#
# [-] Exapnading at depth 8
#
# 1 6 _
# 7 3 2
# 5 4 8
#
# [-] Exapnading at depth 8
#
# _ 1 6
# 7 3 2
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 7 2 8
# 5 4 _
#
# [-] Exapnading at depth 8
#
# 1 3 _
# 7 2 6
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 5 _ 8
# 4 3 7
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 5 3 8
# _ 4 7
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 5 7 3
# 4 8 _
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 5 7 3
# _ 4 8
#
# [-] Exapnading at depth 8
#
# 1 2 _
# 5 6 3
# 4 7 8
#
# [-] Exapnading at depth 8
#
# _ 1 2
# 5 6 3
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 4 5 3
# _ 7 8
#
# [-] Exapnading at depth 8
#
# _ 6 2
# 1 5 3
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 4 _ 2
# 7 3 8
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 4 3 2
# 7 8 _
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 3 7 2
# 4 8 _
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 3 7 2
# _ 4 8
#
# [-] Exapnading at depth 8
#
# 5 6 _
# 3 1 2
# 4 7 8
#
# [-] Exapnading at depth 8
#
# _ 5 6
# 3 1 2
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 3 2 8
# 4 7 _
#
# [-] Exapnading at depth 8
#
# 5 1 _
# 3 2 6
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 6 _
# 5 3 8
# 4 2 7
#
# [-] Exapnading at depth 8
#
# _ 1 6
# 5 3 8
# 4 2 7
#
# [-] Exapnading at depth 8
#
# 1 3 _
# 5 8 6
# 4 2 7
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 4 5 8
# _ 2 7
#
# [-] Exapnading at depth 8
#
# _ 3 6
# 1 5 8
# 4 2 7
#
# [-] Exapnading at depth 8
#
# _ 3 6
# 1 2 8
# 5 4 7
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 2 _ 8
# 5 4 7
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 5 7 6
# 4 8 _
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 5 7 6
# _ 4 8
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 5 6 8
# 4 7 _
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 4 5 6
# _ 7 8
#
# [-] Exapnading at depth 8
#
# _ 2 3
# 1 5 6
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 5 1 3
# 4 2 6
# _ 7 8
#
# [-] Exapnading at depth 8
#
# 5 1 3
# 2 _ 6
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 6 _
# 4 3 2
# 7 5 8
#
# [-] Exapnading at depth 8
#
# _ 1 6
# 4 3 2
# 7 5 8
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 4 2 8
# 7 5 _
#
# [-] Exapnading at depth 8
#
# 1 3 _
# 4 2 6
# 7 5 8
#
# [-] Exapnading at depth 8
#
# _ 3 6
# 1 4 2
# 7 5 8
#
# [-] Exapnading at depth 8
#
# 1 3 _
# 4 5 6
# 7 8 2
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 4 _ 5
# 7 8 2
#
# [-] Exapnading at depth 8
#
# 3 5 6
# 1 7 2
# 4 8 _
#
# [-] Exapnading at depth 8
#
# 3 5 6
# 1 7 2
# _ 4 8
#
# [-] Exapnading at depth 8
#
# 3 5 6
# 1 2 8
# 4 7 _
#
# [-] Exapnading at depth 8
#
# 3 5 _
# 1 2 6
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 3 5 6
# 4 1 2
# _ 7 8
#
# [-] Exapnading at depth 8
#
# 3 6 2
# 1 5 8
# 4 7 _
#
# [-] Exapnading at depth 8
#
# 3 6 2
# 1 _ 5
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 7 3
# 5 8 6
# 4 2 _
#
# [-] Exapnading at depth 8
#
# 1 7 3
# 5 8 6
# _ 4 2
#
# [-] Exapnading at depth 8
#
# 1 7 3
# 5 6 2
# 4 8 _
#
# [-] Exapnading at depth 8
#
# 1 7 _
# 5 6 3
# 4 8 2
#
# [-] Exapnading at depth 8
#
# 1 7 3
# 4 5 6
# _ 8 2
#
# [-] Exapnading at depth 8
#
# _ 7 3
# 1 5 6
# 4 8 2
#
# [-] Exapnading at depth 8
#
# 5 1 3
# 4 7 6
# _ 8 2
#
# [-] Exapnading at depth 8
#
# 5 1 3
# 7 _ 6
# 4 8 2
#
# [-] Exapnading at depth 8
#
# _ 3 6
# 1 8 7
# 5 4 2
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 8 _ 7
# 5 4 2
#
# [-] Exapnading at depth 8
#
# 1 6 7
# 5 3 2
# 4 8 _
#
# [-] Exapnading at depth 8
#
# 1 6 7
# 5 _ 3
# 4 8 2
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 4 3 7
# _ 8 2
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 3 _ 7
# 4 8 2
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 4 _ 7
# 8 5 2
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 4 5 7
# 8 2 _
#
# [-] Exapnading at depth 8
#
# 3 5 6
# 1 _ 7
# 4 8 2
#
# [-] Exapnading at depth 8
#
# 3 6 _
# 1 5 7
# 4 8 2
#
# [-] Exapnading at depth 8
#
# 3 7 6
# 1 4 2
# 5 8 _
#
# [-] Exapnading at depth 8
#
# 3 7 6
# 1 4 2
# _ 5 8
#
# [-] Exapnading at depth 8
#
# 3 7 6
# 1 2 8
# 5 4 _
#
# [-] Exapnading at depth 8
#
# 3 7 _
# 1 2 6
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 3 7 6
# 5 1 2
# _ 4 8
#
# [-] Exapnading at depth 8
#
# _ 7 6
# 3 1 2
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 3 6 2
# 1 7 8
# 5 4 _
#
# [-] Exapnading at depth 8
#
# 3 6 2
# 1 _ 7
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 1 3 _
# 7 4 6
# 5 8 2
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 7 _ 4
# 5 8 2
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 7 3 8
# 5 4 _
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 7 _ 3
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 7 1 6
# 5 3 2
# _ 4 8
#
# [-] Exapnading at depth 8
#
# 7 1 6
# 3 _ 2
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 7 _ 8
# 5 2 4
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 7 2 8
# _ 5 4
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 7 _ 6
# 5 4 8
#
# [-] Exapnading at depth 8
#
# _ 1 3
# 7 2 6
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 1 2 _
# 5 6 8
# 4 3 7
#
# [-] Exapnading at depth 8
#
# _ 1 2
# 5 6 8
# 4 3 7
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 5 8 7
# 4 3 _
#
# [-] Exapnading at depth 8
#
# 1 6 _
# 5 8 2
# 4 3 7
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 4 5 8
# _ 3 7
#
# [-] Exapnading at depth 8
#
# _ 6 2
# 1 5 8
# 4 3 7
#
# [-] Exapnading at depth 8
#
# _ 6 2
# 1 3 8
# 5 4 7
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 3 _ 8
# 5 4 7
#
# [-] Exapnading at depth 8
#
# 1 6 _
# 5 7 2
# 4 8 3
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 5 _ 7
# 4 8 3
#
# [-] Exapnading at depth 8
#
# _ 6 2
# 1 7 3
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 5 1 2
# 4 6 3
# _ 7 8
#
# [-] Exapnading at depth 8
#
# 5 1 2
# 6 _ 3
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 4 _ 3
# 7 5 8
#
# [-] Exapnading at depth 8
#
# 1 6 2
# 4 5 3
# 7 8 _
#
# [-] Exapnading at depth 8
#
# 6 5 2
# 1 _ 3
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 6 2 _
# 1 5 3
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 5 6 _
# 4 1 2
# 7 3 8
#
# [-] Exapnading at depth 8
#
# _ 5 6
# 4 1 2
# 7 3 8
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 4 2 8
# 7 3 _
#
# [-] Exapnading at depth 8
#
# 5 1 _
# 4 2 6
# 7 3 8
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 7 4 2
# _ 3 8
#
# [-] Exapnading at depth 8
#
# _ 1 6
# 5 4 2
# 7 3 8
#
# [-] Exapnading at depth 8
#
# 5 1 _
# 4 3 6
# 7 8 2
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 4 _ 3
# 7 8 2
#
# [-] Exapnading at depth 8
#
# 5 1 _
# 3 7 6
# 4 8 2
#
# [-] Exapnading at depth 8
#
# _ 1 6
# 5 7 2
# 3 4 8
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 7 _ 2
# 3 4 8
#
# [-] Exapnading at depth 8
#
# 5 6 2
# 3 1 8
# 4 7 _
#
# [-] Exapnading at depth 8
#
# 5 6 2
# 3 _ 1
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 3 _ 8
# 4 2 7
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 3 2 8
# _ 4 7
#
# [-] Exapnading at depth 8
#
# 5 2 1
# 3 _ 6
# 4 7 8
#
# [-] Exapnading at depth 8
#
# _ 5 1
# 3 2 6
# 4 7 8
#
# [-] Exapnading at depth 8
#
# 1 6 8
# 5 3 7
# 4 2 _
#
# [-] Exapnading at depth 8
#
# 1 6 8
# 5 _ 3
# 4 2 7
#
# [-] Exapnading at depth 8
#
# 5 1 6
# 4 3 8
# _ 2 7
#
# [-] Exapnading at depth 8
#
# 1 8 3
# 5 _ 6
# 4 2 7
#
# [-] Exapnading at depth 8
#
# _ 1 3
# 5 8 6
# 4 2 7
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 4 _ 8
# 2 5 7
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 4 5 8
# 2 7 _
#
# [-] Exapnading at depth 8
#
# 3 5 6
# 1 _ 8
# 4 2 7
#
# [-] Exapnading at depth 8
#
# 3 6 _
# 1 5 8
# 4 2 7
#
# [-] Exapnading at depth 8
#
# 3 2 6
# 1 _ 8
# 5 4 7
#
# [-] Exapnading at depth 8
#
# 3 6 _
# 1 2 8
# 5 4 7
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 2 4 8
# 5 7 _
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 2 4 8
# _ 5 7
#
# [-] Exapnading at depth 8
#
# 1 6 _
# 2 3 8
# 5 4 7
#
# [-] Exapnading at depth 8
#
# _ 1 6
# 2 3 8
# 5 4 7
#
# [-] Exapnading at depth 8
#
# 1 3 6
# 2 8 7
# 5 4 _
#
# [-] Exapnading at depth 8
#
# 1 3 _
# 2 8 6
# 5 4 7
#
# [-] Exapnading at depth 8
#
# 1 2 _
# 5 7 3
# 4 8 6
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 5 _ 7
# 4 8 6
#
# [-] Exapnading at depth 8
#
# _ 2 3
# 1 7 6
# 5 4 8
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 5 _ 8
# 4 6 7
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 5 6 8
# _ 4 7
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 4 _ 6
# 7 5 8
#
# [-] Exapnading at depth 8
#
# 1 2 3
# 4 5 6
# 7 8 _
# successfull 474
# Goal state reached!!
# 1 2 3
# 4 5 6
# 7 8 _
# Solution found at depth 8
# Algorithm took 2.43701 seconds to complete

# %% [markdown]
# # Comparing the time taken by algorithm for the puzzle of depth 4

# %%
import plotly.express as px
import pandas as pd
B = ['UCS','AMT','AMD']
A=[2.43705,0.02841,0.0261]
# https://cmdlinetips.com/2018/01/how-to-create-pandas-dataframe-from-multiple-lists/
data_tuples = list(zip(B,A))
df=pd.DataFrame(data_tuples, columns=['Algorithm','Time'])
# https://plotly.com/python/bar-charts/
px.bar(df,x='Algorithm',y='Time', title="Time Compared for the puzzle with depth 4").show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="64818108-b8cb-4fd8-94ae-0b8690a0e3f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64818108-b8cb-4fd8-94ae-0b8690a0e3f1")) {                    Plotly.newPlot(                        "64818108-b8cb-4fd8-94ae-0b8690a0e3f1",                        [{"alignmentgroup":"True","hovertemplate":"Algorithm=%{x}<br>Time=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["UCS","AMT","AMD"],"xaxis":"x","y":[2.43705,0.02841,0.0261],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidt ...
